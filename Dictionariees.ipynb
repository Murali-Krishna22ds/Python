# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali-Krishna22ds/December2025GenAI/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type({})
# Out:
# dict

# %%
student={"name":"data science","duration":6}
print(student['name'])
print(student['duration'])
# Out:
# data science
# 6

# %%
s={20:"data science"}
s[20]
# Out:
# 'data science'

# %%
s={20.6:"data science"}
s[20.6]
# Out:
# 'data science'

# %%
s={20+3j:"data science"}
s[20+3j]
# Out:
# 'data science'

# %%
s={True:"data science"}
s[True]
# Out:
# 'data science'

# %%
s={(1,2,3):"data science"}
s[(1,2,3)]
# Out:
# 'data science'

# %%
s={[1,2,3]:"data science"}
#List is unhashable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3547474797.py in <cell line: 0>()
# ----> 1 s={[1,2,3]:"data science"}
#       2 #List is unhashable
#
# TypeError: unhashable type: 'list'

# %%
Employee_data={

      "EMP001":{
          "name":"Rahul",
          "age":29,
          "department":"Finance"
      },

      "EMP002":{
          "name":"Raju",
          "age":32,
          "department":"HR"
      }

}

# %%
Employee_data['EMP001']["department"]
# Out:
# 'Finance'

# %%
Employee_data['EMP002']["age"]
# Out:
# 32

# %%
d={1:"one",2:"two"}
d.keys()
# Out:
# dict_keys([1, 2])

# %%
d.values()
# Out:
# dict_values(['one', 'two'])

# %%
d.items()
# Out:
# dict_items([(1, 'one'), (2, 'two')])

# %%
d[1]="machine"
d
# Out:
# {1: 'machine', 2: 'two'}

# %%
d={1:"one",2:"two"}
d[3]="three"
d["data"]="three"
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 'data': 'three'}

# %%
d.pop(1)
# Out:
# 'one'

# %%
d
# Out:
# {2: 'two', 3: 'three', 'data': 'three'}

# %%
d.popitem()
# Out:
# ('data', 'three')

# %%
d
# Out:
# {2: 'two', 3: 'three'}

# %%
d.clear()
d
# Out:
# {}
